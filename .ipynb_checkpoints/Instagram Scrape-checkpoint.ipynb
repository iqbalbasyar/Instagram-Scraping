# %% [markdown]
# Source :
# https://medium.com/@srujana.rao2/scraping-instagram-with-python-using-selenium-and-beautiful-soup-8b72c186a058

# %% [markdown]
# # Dependencies
#
# ### 1. Selenium
# Selenium is a packahe to automate interaction trough your browser. You can install selenium using
# ```
# pip install selenium
# ```
# or
# ```
# conda install -c conda-forge selenium
# ```
# Depending on what source you want to install from

# %%
import selenium
print(selenium.__version__)
# Out:
# 3.141.0

# %% [markdown]
# ### 2.  Chrome Web Driver
# Web driver is tool that provides the capabilites of controlling the browser automatically. I'm using `Google Chrome`, so let's use `ChromeDriver` that you can download from http://chromedriver.chromium.org/. And make sure you save it on accessable path
#
# There are several compatibilities within `ChromeDriver`, so make sure you have the latest version of `Google Chrome`
#
# I'm currently using Chrome ver. 77.0.3865.75 and ChromeDriver ver. 77.0.3865.40

# %%
import json
import numpy as np
import pandas as pd
import re
import time

from bs4 import BeautifulSoup as bs
from pandas.io.json import json_normalize
from selenium import webdriver
from urllib.request import urlopen

# %%
# constants
# username='iqbalbasyar'
# username='officialsamuel'
username='ridwankamil'

chrome_driver_path = 'chromedriver.exe'

browser = webdriver.Chrome(chrome_driver_path)
browser.get('https://www.instagram.com/'+username)
Pagelength = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %% [markdown]
# # Parse HTML

# %% [markdown]
# By default, selenium only open the first page. For instagram cases when you're up to looking for another images by scrolling, you can use the selenium to scroll and get all the links (since instagram loads all the post into one long page)

# %%
Pagelength = browser.execute_script("window.scrollTo(0, document.body.scrollHeight/1.5);")

links= set()
source = browser.page_source
data=bs(source, 'html.parser')
body = data.find('body')
script = body.find('span')
for link in script.findAll('a'):
     if re.match("/p", link.get('href')):
        links.add('https://www.instagram.com'+link.get('href'))
#instagram may interrupt the code , so we set a sleep time for each scrolling
time.sleep(2) 
Pagelength = browser.execute_script("window.scrollTo(document.body.scrollHeight/1.5, document.body.scrollHeight/3.0);")

source = browser.page_source
data=bs(source, 'html.parser')
body = data.find('body')
script = body.find('span')
for link in script.findAll('a'):
     if re.match("/p", link.get('href')):
        links.add('https://www.instagram.com'+link.get('href'))

# %% [markdown]
# While scrolling, the browser might see previous post, so I used set to remove duplicates

# %%
len(links)
# Out:
# 36

# %%
script
# Out:
# <span id="react-root"><form enctype="multipart/form-data" method="POST" role="presentation"><input accept="image/jpeg" class="tb_sK" type="file"/></form><section class="_9eogI E3X2T"><div></div><main class="SCxLW o64aR" role="main"><div class="v9tJq"><header class="vtbgv"><div class="XjzKX"><div class="RR-M-" role="button" tabindex="0"><canvas class="CfWVH" height="168" style="position: absolute; top: -9px; left: -9px; width: 168px; height: 168px;" width="168"></canvas><span class="_2dbep" role="link" style="width: 150px; height: 150px;" tabindex="0"><img alt="ridwankamil's profile picture" class="_6q-tv" src="https://instagram.fcgk6-1.fna.fbcdn.net/vp/fd64e426a3dcddd44dbfeefee1d4ab33/5E37083A/t51.2885-19/s150x150/49985298_1152337374929687_148358169087705088_n.jpg?_nc_ht=instagram.fcgk6-1.fna.fbcdn.net"/></span></div></div><section class="zwlfE"><div class="nZSzR"><h1 class="_7UhW9 fKFbl yUEEX KV-D4 fDxYl">ridwankamil</h1><span class="mrEK_ Szr5J coreSpriteVerifiedBadge" title="Verif
# ...

# %% [markdown]
# # Get the comments

# %% [markdown]
# Now that we have access to the posts (via link), let's get information from the post. We only focus on **comment**

# %%
result=pd.DataFrame()
for i in range(len(links)):
    try:
        page = urlopen(links[i]).read()
        data=bs(page, 'html.parser')
        body = data.find('body')
        script = body.find('script')
        raw = script.text.strip().replace('window._sharedData =', '').replace(';', '')
        json_data=json.loads(raw)
        posts =json_data['entry_data']['PostPage'][0]['graphql']
        posts= json.dumps(posts)
        posts = json.loads(posts)
        x = pd.DataFrame.from_dict(json_normalize(posts), orient='columns') 
        x.columns =  x.columns.str.replace("shortcode_media.", "")
        result=result.append(x)
       
    except:
        np.nan
#Just check for the duplicates
result = result.drop_duplicates(subset = 'shortcode')
result.index = range(len(result.index))

# %%
# for _i in result['video_url'] :
#     print(pd.isna(_i))

# %%
result=pd.DataFrame()
for i in range(len(links)):
    try:
        page = urlopen(links[i]).read()
        data=bs(page, 'html.parser')
        body = data.find('body')
        script = body.find('script')
        raw = script.text.strip().replace('window._sharedData =', '').replace(';', '')
        json_data=json.loads(raw)
        posts =json_data['entry_data']['PostPage'][0]['graphql']['shortcode_media']['edge_media_to_parent_comment']
        comment_count = posts['count']
        comments = posts['edges'] #it's the main comment 
        for main_comment in comments:
#             print (main_comment['node']['text'])
            try:
                thread_comment = main_comment['node']['edge_threaded_comments']
                for replies in thread_comment['edges'] :
#                     print(replies['node']['text'])
            except:
                pass
        

        posts= json.dumps(posts)
        posts = json.loads(posts)
        x = pd.DataFrame.from_dict(json_normalize(posts), orient='columns') 
        x.columns =  x.columns.str.replace("shortcode_media.", "")
        result=result.append(x)
       
    except:
        np.nan

# %%
result
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Download Display Image

# %%
import os
import requests

result.index = range(len(result.index))
directory="downloaded/"
# for i in range(len(result)):    
#     r = requests.get(result['display_url'][i])
    
#     # check if the data is video or image
#     if pd.isna(result['video_url'][i]):
#         r = requests.get(result['display_url'][i])
#         with open(directory+result['shortcode'][i]+".jpg", 'wb') as f:
#                         f.write(r.content)
#     else:
#         r = requests.get(result['video_url'][i])
#         with open(directory+result['shortcode'][i]+".mp4", 'wb') as f:
#                         f.write(r.content)
for i in range(len(result)):
    r = requests.get(result['display_url'][i])
    with open(directory+result['shortcode'][i]+".jpg", 'wb') as f:
                    f.write(r.content)

# %%
result
# Out:
#       __typename                              accessibility_caption  \
# 0   GraphSidecar                                                NaN
# 1   GraphSidecar                                                NaN
# 2   GraphSidecar                                                NaN
# 3     GraphImage                    No photo description available.
# 4     GraphImage                    No photo description available.
# 5     GraphImage                    No photo description available.
# 6   GraphSidecar                                                NaN
# 7   GraphSidecar                                                NaN
# 8     GraphImage              Image may contain: 1 person, standing
# 9     GraphImage                            Image may contain: text
# 10    GraphImage  Image may contain: 2 people, ocean, outdoor an...
# 11  GraphSidecar                                                NaN
# 12    GraphImage  Image may contain: one or more people and peop...
# ...

# %% [markdown]
# # Ver 2
# source : https://edmundmartin.com/scraping-instagram-with-python/

# %%
from random import choice
import json

import requests
from bs4 import BeautifulSoup

_user_agents = [
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36'
]


class InstagramScraper:

    def __init__(self, user_agents=None, proxy=None):
        self.user_agents = user_agents
        self.proxy = proxy

    def __random_agent(self):
        if self.user_agents and isinstance(self.user_agents, list):
            return choice(self.user_agents)
        return choice(_user_agents)

    def __request_url(self, url):
        try:
            response = requests.get(url, headers={'User-Agent': self.__random_agent()}, proxies={'http': self.proxy,
                                                                                                 'https': self.proxy})
            response.raise_for_status()
        except requests.HTTPError:
            raise requests.HTTPError('Received non 200 status code from Instagram')
        except requests.RequestException:
            raise requests.RequestException
        else:
            return response.text
        

    def extract_json_data(html):
        soup = BeautifulSoup(html, 'html.parser')
        body = soup.find('body')
        script_tag = body.find('script')
        raw_string = script_tag.text.strip().replace('window._sharedData =', '').replace(';', '')
        return json.loads(raw_string)
        
        
    def profile_page_metrics(self, profile_url):
        results = {}
        try:
            response = self.__request_url(profile_url)
            json_data = self.extract_json_data(response)
            metrics = json_data['entry_data']['ProfilePage'][0]['graphql']['user']
        except Exception as e:
            raise e
        else:
            for key, value in metrics.items():
                if key != 'edge_owner_to_timeline_media':
                    if value and isinstance(value, dict):
                        value = value['count']
                        results[key] = value
                    elif value:
                        results[key] = value
        return results

    def profile_page_recent_posts(self, profile_url):
        results = []
        try:
            response = self.__request_url(profile_url)
            json_data = self.extract_json_data(response)
            metrics = json_data['entry_data']['ProfilePage'][0]['graphql']['user']['edge_owner_to_timeline_media']["edges"]
        except Exception as e:
            raise e
        else:
            for node in metrics:
                node = node.get('node')
                if node and isinstance(node, dict):
                    results.append(node)
        return results

# %%
from pprint import pprint

k = InstagramScraper()
results = k.profile_page_recent_posts('https://www.instagram.com/iqbalbasyar/?hl=en')
pprint(results)
# Out:
# [{'__typename': 'GraphImage',
#   'accessibility_caption': 'Image may contain: one or more people, people '
#                            'standing, tree, snow, sky, outdoor and nature',
#   'comments_disabled': False,
#   'dimensions': {'height': 1080, 'width': 1080},
#   'display_url': 'https://instagram.fcgk6-1.fna.fbcdn.net/vp/be74a53699fd2e8254ab6c406f6ea3ca/5E0D8A4F/t51.2885-15/e35/s1080x1080/69420271_2188644648104201_6172048796853388528_n.jpg?_nc_ht=instagram.fcgk6-1.fna.fbcdn.net&_nc_cat=105',
#   'edge_liked_by': {'count': 64},
#   'edge_media_preview_like': {'count': 64},
#   'edge_media_to_caption': {'edges': [{'node': {'text': 'This is the first and '
#                                                         'the last place that I '
#                                                         'went in my school '
#                                                         'period. I closed a '
#                                                         'cycle and shifted to '
# ...

# %% [markdown]
# # Scrap manuals

# %%
_link = 'https://www.instagram.com/p/B2eIAHvA5r2/'

# %%
_link
# Out:
# 'https://www.instagram.com/p/B2eIAHvA5r2/'

# %%
result=pd.DataFrame()

page = urlopen(_link).read()
data=bs(page, 'html.parser')
body = data.find('body')
script = body.find('script')
raw = script.text.strip().replace('window._sharedData =', '').replace(';', '')
json_data=json.loads(raw)
posts =json_data['entry_data']['PostPage'][0]['graphql']
posts= json.dumps(posts)
posts = json.loads(posts)
x = pd.DataFrame.from_dict(json_normalize(posts), orient='columns') 
x.columns =  x.columns.str.replace("shortcode_media.", "")
result=result.append(x)

# %%
posts =json_data['entry_data']['PostPage'][0]['graphql']['shortcode_media']['edge_media_to_parent_comment']

# %%
script
# Out:
# <script type="text/javascript">window._sharedData = {"config":{"csrf_token":"mN0p1W8RS4Vv4jbtczhskvala8N7riFi","viewer":null,"viewerId":null},"country_code":"ID","language_code":"en","locale":"en_US","entry_data":{"PostPage":[{"graphql":{"shortcode_media":{"__typename":"GraphSidecar","id":"2134178466097240822","shortcode":"B2eIAHvA5r2","dimensions":{"height":1080,"width":1080},"gating_info":null,"fact_check_information":null,"media_preview":null,"display_url":"https://instagram.fcgk6-1.fna.fbcdn.net/vp/2d4c97881959a6f21412dfb66676d28c/5E1BB30E/t51.2885-15/e35/69937424_474749140040012_1373966758265169475_n.jpg?_nc_ht=instagram.fcgk6-1.fna.fbcdn.net\u0026_nc_cat=1","display_resources":[{"src":"https://instagram.fcgk6-1.fna.fbcdn.net/vp/067a7472c2237e41c5eb27a361b74104/5E3859EB/t51.2885-15/sh0.08/e35/s640x640/69937424_474749140040012_1373966758265169475_n.jpg?_nc_ht=instagram.fcgk6-1.fna.fbcdn.net\u0026_nc_cat=1","config_width":640,"config_height":640},{"src":"https://instagram.fcgk6-1.
# ...

# %%
#check is there any comments
comment_count = posts['count']
comments = posts['edges'] #it's the main comment 
for main_comment in comments:
    print(main_comment['node'])
#     print (main_comment['node']['text'])
    try:
        thread_comment = main_comment['node']['edge_threaded_comments']
#         print(len(thread_comment['edges']))
        for replies in thread_comment['edges'] :
            pass
#             print(replies)
#             print(replies['node']['text'])
    except:
        pass
    print()
# Out:
# {'id': '17842366792680252', 'text': 'Save Bandung kota kuliner', 'created_at': 1568696478, 'did_report_as_spam': False, 'owner': {'id': '7946250327', 'is_verified': False, 'profile_pic_url': 'https://instagram.fcgk6-1.fna.fbcdn.net/vp/8a72c5055ca6e0d392b5abbb2a594fab/5E0333E5/t51.2885-19/s150x150/61111901_1333412916813878_7591099424298762240_n.jpg?_nc_ht=instagram.fcgk6-1.fna.fbcdn.net', 'username': 'uaisabdullah'}, 'viewer_has_liked': False, 'edge_liked_by': {'count': 0}, 'edge_threaded_comments': {'count': 0, 'page_info': {'has_next_page': False, 'end_cursor': None}, 'edges': []}}
#
# ...

# %%
print(comment_count)
# Out:
# 685

# %%
print(len(comments))
# Out:
# 23

# %%
json_data
# Out:
# {'config': {'csrf_token': 'NuXAiWdH8F1DdGzLwgJ6EYKR70XSZYs5',
#   'viewer': None,
#   'viewerId': None},
#  'country_code': 'ID',
#  'language_code': 'en',
#  'locale': 'en_US',
#  'entry_data': {'PostPage': [{'graphql': {'shortcode_media': {'__typename': 'GraphImage',
#       'id': '2125606455663193794',
#       'shortcode': 'B1_q886FO7C',
#       'dimensions': {'height': 1080, 'width': 1080},
#       'gating_info': None,
#       'fact_check_information': None,
#       'media_preview': '...',
#       'display_url': 'https://instagram.fcgk6-1.fna.fbcdn.net/vp/be74a53699fd2e8254ab6c406f6ea3ca/5E0D8A4F/t51.2885-15/e35/s1080x1080/69420271_2188644648104201_6172048796853388528_n.jpg?_nc_ht=instagram.fcgk6-1.fna.fbcdn.net&_nc_cat=105',
# ...

# %%
result.columns
# Out:
# Index(['__typename', 'accessibility_caption', 'caption_is_edited',
#        'comments_disabled', 'dimensions.height', 'dimensions.width',
#        'display_resources', 'display_url', 'edge_media_preview_comment.count',
#        'edge_media_preview_comment.edges', 'edge_media_preview_like.count',
#        'edge_media_preview_like.edges', 'edge_media_to_caption.edges',
#        'edge_media_to_parent_comment.count',
#        'edge_media_to_parent_comment.edges',
#        'edge_media_to_parent_comment.page_info.end_cursor',
#        'edge_media_to_parent_comment.page_info.has_next_page',
#        'edge_media_to_sponsor_user.edges', 'edge_media_to_tagged_user.edges',
#        'edge_web_media_to_related_media.edges', 'fact_check_information',
#        'gating_info', 'has_ranked_comments', 'id', 'is_ad', 'is_video',
#        'location.address_json', 'location.has_public_page', 'location.id',
#        'location.name', 'location.slug', 'media_preview',
# ...

# %%
links= set()
source = browser.page_source
data=bs(source, 'html.parser')
body = data.find('body')
script = body.find('span')
for link in script.findAll('a'):
     if re.match("/p", link.get('href')):
        links.add('https://www.instagram.com'+link.get('href'))
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-216-2801749cb7d2> in <module>
#       1 links= set()
# ----> 2 source = browser.page_source
#       3 data=bs(source, 'html.parser')
#       4 body = data.find('body')
#       5 script = body.find('span')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
# ...
