# %% [markdown]
# # Instagram Open Profile Scraping
# <p style='text-align: justify;'>
# This notebook will scrape somone's profile using his/her username. The main data to be collected are profile informations and post's details, with the media (image) itself. For example, i'm using Samuel Chan's Instagram Profile (@officialsamuel).
#
# *Note* :
#
# There may some other easier way to scrap a web page. But in this case, Instagram does not provide all the link in **one page** (It's an infinity scroll page !). So we have to manually scroll the page to continue collecting the links (for the post). That's why I use chrome web driver to help me automatically scroll the page using selenium.
# </p>

# %% [markdown]
# # Dependencies
#
# ### Selenium
# Selenium is a package to automate interaction trough your browser. You can install selenium using
# `
# pip install selenium
# `
# or
# `
# conda install -c conda-forge selenium
# `
# Depending on what source you want to install from.

# %%
import selenium
print(selenium.__version__)
# Out:
# 3.141.0

# %% [markdown]
# ### Chrome Web Driver
# Web driver is tool that provides the capabilites of controlling the browser automatically. I'm using `Google Chrome`, so I decided to use `ChromeDriver` that you can download from http://chromedriver.chromium.org/. And make sure you save it on accessable path
#
# Please mind the compatibilities within `ChromeDriver` and `Google Chrome`. I'm currently using Chrome ver. 77.0.3865.75 and ChromeDriver ver. 77.0.3865.40

# %%
import json
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os
import pandas as pd
import plotly 
import plotly.graph_objs as go

import re
import requests
import time
import warnings

from bs4 import BeautifulSoup as bs
from datetime import date
from pandas.io.json import json_normalize
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from selenium import webdriver
from tqdm import tqdm
from urllib.request import urlopen

# %matplotlib inline
warnings.filterwarnings("ignore", module="matplotlib")

init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Web Scraping

# %% [markdown]
# ## Open the browser
# *This may take a while according to your computer speed)*

# %%
# constants
# username='iqbalbasyar'
username='officialsamuel'
# username = 'iraseugin'
# username = 'teamalgoritma'

chrome_driver_path = 'chromedriver.exe'
browser = webdriver.Chrome(chrome_driver_path)
browser.get('https://www.instagram.com/'+username)

# %% [markdown]
# ## Get the profile information

# %%
page = urlopen('https://www.instagram.com/'+username).read()
data = bs(page, 'html.parser')
body = data.find('body')
script = body.find('script')
raw = script.text.strip().replace('window._sharedData =', '').replace(';', '')
json_data = json.loads(raw)

# %%
profile = json_data['entry_data']['ProfilePage'][0]['graphql']

# %%
p_name = profile['user']['full_name']
p_username = profile['user']['username']
p_follower = profile['user']['edge_followed_by']['count']
p_follow = profile['user']['edge_follow']['count']
p_n_post = profile['user']['edge_owner_to_timeline_media']['count']
_data = {'username':p_username, 'name':p_name, 'follower':p_follower, 'following':p_follow, 'post':p_n_post}
df_profile = pd.DataFrame(data=_data, index=['username'])
df_profile
# Out:
#                 username    name  follower  following  post
# username  officialsamuel  Samuel       341         84    51

# %% [markdown]
# ## Get the media (post) informations

# %%
max_post = 200 #depends on how many post you want to scrape
max_post = min(max_post, df_profile['post'].values[0])
max_post
# Out:
# 51

# %% [markdown]
# ### 1. Collect all the link by scrolling

# %%
links = set()
browser.execute_script('window.scrollTo(0, 0)')
while len(links) < max_post:
    prev_len = len(links)
    source = browser.page_source
    data=bs(source, 'html.parser')
    body = data.find('body')
    script = body.find('span')
    for link in script.findAll('a'):
        if re.match("/p", link.get('href')):
            links.add('https://www.instagram.com'+link.get('href'))
    if len(links) != prev_len : print('Collected Post : {}/{}'.format(len(links), max_post))
    browser.execute_script('window.scrollTo(0, document.body.scrollHeight)')
    page_load = browser.execute_script('return document.readyState')
    while page_load != 'complete':
        page_load = browser.execute_script('return document.readyState')
        time.sleep(2)
# Out:
# Collected Post : 24/51
# Collected Post : 36/51
# Collected Post : 48/51
# Collected Post : 51/51

# %% [markdown]
# ### 2. Access the media
# Scrape several informations about the posts. I want to get :
# - Post ID
# - Number of likes
# - Number of comments
# - Timestamp
# - The display image

# %%
result=pd.DataFrame()
for link in tqdm(links):
    try:
        page = urlopen(link).read()
        data=bs(page, 'html.parser')
        body = data.find('body')
        script = body.find('script')
        raw = script.text.strip().replace('window._sharedData =', '').replace(';', '')
        json_data=json.loads(raw)
        posts =json_data['entry_data']['PostPage'][0]['graphql']
        posts= json.dumps(posts)
        posts = json.loads(posts)
        x = pd.DataFrame.from_dict(json_normalize(posts), orient='columns') 
        x.columns =  x.columns.str.replace("shortcode_media.", "")
        result=result.append(x)
       
    except:
        np.nan
# Out:
#   4%|███▎                                                                               | 2/51 [00:03<01:17,  1.58s/it]C:\Users\dzul\Anaconda3\lib\site-packages\pandas\core\frame.py:7123: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#
# 100%|██████████████████████████████████████████████████████████████████████████████████| 51/51 [00:50<00:00,  1.02it/s]

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 0
# Data columns (total 64 columns):
# __typename                                              51 non-null object
# accessibility_caption                                   42 non-null object
# caption_is_edited                                       51 non-null bool
# comments_disabled                                       51 non-null bool
# dash_info.is_dash_eligible                              1 non-null object
# dash_info.number_of_qualities                           1 non-null float64
# dash_info.video_dash_manifest                           0 non-null object
# dimensions.height                                       51 non-null int64
# dimensions.width                                        51 non-null int64
# display_resources                                       51 non-null object
# display_url                                             51 non-null object
# edge_media_preview_comment.count                        51 non-null int64
# edge_media_preview_comment.edges                        51 non-null object
# edge_media_preview_like.count                           51 non-null int64
# edge_media_preview_like.edges                           51 non-null object
# edge_media_to_caption.edges                             51 non-null object
# edge_media_to_parent_comment.count                      51 non-null int64
# edge_media_to_parent_comment.edges                      51 non-null object
# edge_media_to_parent_comment.page_info.end_cursor       0 non-null object
# edge_media_to_parent_comment.page_info.has_next_page    51 non-null bool
# edge_media_to_sponsor_user.edges                        51 non-null object
# edge_media_to_tagged_user.edges                         51 non-null object
# edge_sidecar_to_children.edges                          8 non-null object
# edge_web_media_to_related_media.edges                   51 non-null object
# encoding_status                                         0 non-null object
# fact_check_information                                  0 non-null object
# gating_info                                             0 non-null object
# has_ranked_comments                                     51 non-null bool
# id                                                      51 non-null object
# is_ad                                                   51 non-null bool
# is_published                                            1 non-null object
# is_video                                                51 non-null bool
# location                                                0 non-null object
# location.address_json                                   32 non-null object
# location.has_public_page                                32 non-null object
# location.id                                             32 non-null object
# location.name                                           32 non-null object
# location.slug                                           32 non-null object
# media_preview                                           41 non-null object
# owner.blocked_by_viewer                                 51 non-null bool
# owner.followed_by_viewer                                51 non-null bool
# owner.full_name                                         51 non-null object
# owner.has_blocked_viewer                                51 non-null bool
# owner.id                                                51 non-null object
# owner.is_private                                        51 non-null bool
# owner.is_unpublished                                    51 non-null bool
# owner.is_verified                                       51 non-null bool
# owner.profile_pic_url                                   51 non-null object
# owner.requested_by_viewer                               51 non-null bool
# owner.username                                          51 non-null object
# product_type                                            1 non-null object
# shortcode                                               51 non-null object
# taken_at_timestamp                                      51 non-null int64
# thumbnail_src                                           1 non-null object
# title                                                   1 non-null object
# tracking_token                                          51 non-null object
# video_duration                                          1 non-null float64
# video_url                                               1 non-null object
# video_view_count                                        1 non-null float64
# viewer_can_reshare                                      51 non-null bool
# viewer_has_liked                                        51 non-null bool
# viewer_has_saved                                        51 non-null bool
# viewer_has_saved_to_collection                          51 non-null bool
# viewer_in_photo_of_you                                  51 non-null bool
# dtypes: bool(18), float64(3), int64(6), object(37)
# memory usage: 19.6+ KB

# %% [markdown]
# Not all of the columns are useful(yet), so I selected only some of them

# %%
# sort by chronological order
result = result.sort_values(by='taken_at_timestamp')

# %%
post_id = result['shortcode']

# %%
post_likes = result['edge_media_preview_like.count']
# post_likes

# %%
post_comments = result['edge_media_to_parent_comment.count']
post_comments = post_comments.fillna(0.0)
# post_comments

# %%
post_timestamp = result['taken_at_timestamp']
post_timestamp = post_timestamp.apply(date.fromtimestamp)
# post_timestamp

# %%
if 'location.name' in result.columns:
    post_location = result['location.name']
    post_location.fillna("None", inplace=True)
else:
    post_location = pd.Series(data=['None']*len(result))
# post_location

# %% [markdown]
# Cons :
# - The location name seems unstructured. Thus, we cannot easily make  heatmap using map based on its location

# %%
_data = {'id' : post_id, 'timestamp' : post_timestamp, 'likes' : post_likes, 'comments' : post_comments}
df_post = pd.DataFrame(data=_data)
df_post['location'] = post_location #changed to this, due to error in case of all "none"

# %%
df_post = df_post.reset_index(drop=True)
df_post.head(10)
# Out:
#             id   timestamp  likes  comments  \
# 0   8tI3_enxaK  2015-10-12      6         1
# 1   80wpktHxUq  2015-10-14      7         2
# 2  BQZOIIbjg_O  2017-02-12     18         0
# 3  BQajkYDj6oN  2017-02-12     16         2
# 4  BQdX3cOjgcX  2017-02-13     13         2
# 5  BQedKjAD-GK  2017-02-14     20         0
# 6  BQfpvF6Dn1-  2017-02-14     12         1
# 7  BQhn47NjJmK  2017-02-15     25         1
# 8  BQnIUk0hHZO  2017-02-17     14         0
# 9  BRIOrFtBx2b  2017-03-02     48         0
#
#                                    location
# 0                                      None
# 1                                      None
# 2                                      None
# 3                                      None
# 4                Vườn nho ba mọi Ninh Thuận
# 5  Cổng Trời Chùa Linh Quy Pháp Ấn Lâm Đồng
# 6                Vườn nho ba mọi Ninh Thuận
# 7                                 Phan Rang
# 8                                      None
# 9                                      None

# %% [markdown]
# ## 3. Download the media (image)
# <p style='text-align: justify;'>
# Save the structured data (df_profile.csv and df_post.csv) and download all the display image for each post. I assume all the media are image and the post are not multi-image type
# </p>

# %%
try:
    os.mkdir(p_username)
except OSError as e:
    pass

download_path = p_username+'/'

for i in tqdm(range(len(result))):
    r = requests.get(result['display_resources'].iloc[i][0]['src'])
    with open(download_path+result['shortcode'].iloc[i]+".jpg", 'wb') as f:
                    f.write(r.content)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 51/51 [01:06<00:00,  1.30s/it]

# %%
export_csv = df_profile.to_csv (p_username+'/profile.csv', index = None , header=True) 
export_csv = df_post.to_csv (p_username+'/post.csv', index = None , header=True)

# %% [markdown]
# # Exploration

# %% [markdown]
# I want to know :
# - most frequent places
# - most commented post
# - most liked post
#
# - interval between post (predict when to post again) to know is he a scheduled person or not
#
# todo:
# - know the characteristic of the posts with image classification

# %% [markdown]
# ### Load the scraped file

# %%
df_profile = pd.read_csv(p_username+'/profile.csv')
df_profile
# Out:
#          username    name  follower  following  post
# 0  officialsamuel  Samuel       341         84    51

# %%
df_post = pd.read_csv(p_username+'/post.csv', index_col='timestamp')
df_post.head()
# Out:
#                      id  likes  comments                    location
# timestamp
# 2015-10-12   8tI3_enxaK      6         1                        None
# 2015-10-14   80wpktHxUq      7         2                        None
# 2017-02-12  BQZOIIbjg_O     18         0                        None
# 2017-02-12  BQajkYDj6oN     16         2                        None
# 2017-02-13  BQdX3cOjgcX     13         2  Vườn nho ba mọi Ninh Thuận

# %%
df_post.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 2015-10-12 to 2019-09-29
# Data columns (total 4 columns):
# id          51 non-null object
# likes       51 non-null int64
# comments    51 non-null int64
# location    51 non-null object
# dtypes: int64(2), object(2)
# memory usage: 2.0+ KB

# %% [markdown]
# ### Most Frequent Places
# Counting the most tagged places in post

# %%
top5_place = df_post['location'][df_post['location'] != 'None'].value_counts()[:5]
top5_place
# Out:
# Danau Kaolin, Belitung        3
# Algoritma                     3
# Marina Bay Sands              2
# Vườn nho ba mọi Ninh Thuận    2
# HUBBA Thailand                2
# Name: location, dtype: int64

# %%
fig = go.Figure([go.Bar(
    y = top5_place, 
    x = top5_place.index,
    )])
fig.show()

# iplot(fig, filename='top5place.html')
# Out:
# <div>
#
#
#             <div id="e9b96dfa-f9d8-40eb-87a3-85c804341fba" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e9b96dfa-f9d8-40eb-87a3-85c804341fba")) {
#                     Plotly.newPlot(
#                         'e9b96dfa-f9d8-40eb-87a3-85c804341fba',
#                         [{"type": "bar", "uid": "fe2f627e-53cb-466b-8625-ceeb47e10096", "x": ["Danau Kaolin, Belitung", "Algoritma", "Marina Bay Sands", "V\u01b0\u1eddn nho ba m\u1ecdi Ninh Thu\u1eadn", "HUBBA Thailand"], "y": [3, 3, 2, 2, 2]}],
#                         {},
#                         {"plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('e9b96dfa-f9d8-40eb-87a3-85c804341fba');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# notes : I wanted the bins to be stack of the image for each places (I can't do this yet).

# %% [markdown]
# ### Most Commented Post

# %%
top5_comment = df_post.sort_values(by = ['comments'], ascending=False).head(5)
top5_comment
# Out:
#                      id  likes  comments                 location
# timestamp
# 2017-03-30  BSP9BhqBYcF     36         5  Gantung, Belitung Timur
# 2019-07-26  B0YzT1HnVIo     27         5                     None
# 2019-02-15  Bt58Wt8gHs_     77         5          Bali, Indonesia
# 2017-05-05  BTtEYmph5O4     35         4         Marina Bay Sands
# 2019-04-11  BwG7_Hig4dg     56         4                Algoritma

# %%
img = []
for i in top5_comment['id']:
    img.append(mpimg.imread(df_profile['username'].iloc[0]+'/'+i+'.jpg'))

# %%
fig, ax = plt.subplots(1,5,figsize=(20,5))
fig.subplots_adjust(hspace=0.1, wspace=0.1)
for i in range(len(img)):
        ax[i].imshow(img[i])
        ax[i].set_title(str(int(top5_comment['comments'].iloc[i]))+' Comments')
        ax[i].axis('off')
plt.show()

# %% [markdown]
# ### Most Liked Post

# %%
top5_like = df_post.sort_values(by = ['likes'], ascending=False).head(5)
top5_like
# Out:
#                      id  likes  comments         location
# timestamp
# 2019-03-04  BulRtszg1Rx     85         2             None
# 2019-02-15  Bt58Wt8gHs_     77         5  Bali, Indonesia
# 2019-04-11  BwG7_Hig4dg     56         4        Algoritma
# 2019-02-13  Bt05wNRADtn     54         1    IOI City Mall
# 2017-07-06  BWNJqWGBUR4     50         3             None

# %%
img = []
for i in top5_like['id']:
    img.append(mpimg.imread(df_profile['username'][0]+'/'+i+'.jpg'))

# %%
fig, ax = plt.subplots(1,5,figsize=(20,5))
fig.subplots_adjust(hspace=0.1, wspace=0.1)
for i in range(len(img)):
        ax[i].imshow(img[i])
        ax[i].set_title(str(top5_like['likes'].iloc[i])+' likes')
        ax[i].axis('off')
plt.show()

# %% [markdown]
# ### Post activity
# I wanted to know the expected interval between each post

# %%
df_post.index = pd.to_datetime(df_post.index) # Change the index to be datetime type

# %%
set1 = df_post.index[:-1]
set2 = df_post.index[1:]
post_interval = set2- set1

# %%
pd.Series(post_interval).mean()
# Out:
# Timedelta('28 days 23:02:24')

# %%
min(post_interval)
# Out:
# Timedelta('0 days 00:00:00')

# %%
max(post_interval)
# Out:
# Timedelta('487 days 00:00:00')

# %% [markdown]
# ### Post Activity Map

# %%
import calmap

# %%
time_range = pd.date_range(start=df_post.index[0], end=df_post.index[-1])
days = df_post.index
events = pd.Series(np.ones(len(days)), index=days)

# %%
calmap.calendarplot(events, monthticks=1, daylabels='MTWTFSS',
                    dayticks=[0,2,4,6], cmap='YlGn',
                    fillcolor='grey', linewidth=0,
                    fig_kws=dict(figsize=(12, 10)))
# Out:
# C:\Users\dzul\Anaconda3\lib\site-packages\calmap\__init__.py:221: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
# (<Figure size 864x720 with 4 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000020E4BA33F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020E4B2DD550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020E4B8B4908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020E4B677EB8>],
#        dtype=object))

# %% [markdown]
# <p style='text-align: justify;'> Based on the heatmap above, it's clear that Sam don't post often. The biggest space are in between 2nd half of 2015 to the early 2017. <b>Sam's off for half a year</b> , based on the data, at least (assuming there's no deleted posts) </p>

# %% [markdown]
# ### Likes, comments, and follower

# %%
avg_like = df_post['likes'].mean()
avg_comment = df_post['comments'].mean()
follower = df_profile['follower'][0]

# %%
avg_like, avg_comment, follower
# Out:
# (30.529411764705884, 1.3137254901960784, 341)

# %%
colors = [ 'gray', 'lightslategray', 'crimson']

fig = go.Figure(data=[go.Bar(
    x=['average like', 'average comments', 'followers'],
    y=[avg_like, avg_comment, follower],
    marker_color=colors 
)])
fig.layout.update()
iplot(fig)
# Out:
# <div>
#
#
#             <div id="9a7740df-f868-4a89-afec-a11733da0a1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9a7740df-f868-4a89-afec-a11733da0a1a")) {
#                     Plotly.newPlot(
#                         '9a7740df-f868-4a89-afec-a11733da0a1a',
#                         [{"marker": {"color": ["gray", "lightslategray", "crimson"]}, "type": "bar", "uid": "b753f174-058d-4cd0-888c-7b27166d80ef", "x": ["average like", "average comments", "followers"], "y": [30.529411764705884, 1.3137254901960784, 341]}],
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('9a7740df-f868-4a89-afec-a11733da0a1a');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
x = df_post.index
y0 = df_post['likes']
y1 = df_post['comments']

# Create traces
fig = go.Figure()
fig.add_trace(go.Scatter(x=x, y=y0,
                    mode='lines+markers',
                    name='Likes'))
fig.add_trace(go.Scatter(x=x, y=y1,
                    mode='lines+markers',
                    name='Comments'))
fig.show()
# Out:
# <div>
#
#
#             <div id="c048654c-0b88-4d27-9d58-81df48346deb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c048654c-0b88-4d27-9d58-81df48346deb")) {
#                     Plotly.newPlot(
#                         'c048654c-0b88-4d27-9d58-81df48346deb',
#                         [{"mode": "lines+markers", "name": "Likes", "type": "scatter", "uid": "24517f70-e71d-4b9a-bbc5-ddc35311725a", "x": ["2015-10-12", "2015-10-14", "2017-02-12", "2017-02-12", "2017-02-13", "2017-02-14", "2017-02-14", "2017-02-15", "2017-02-17", "2017-03-02", "2017-03-04", "2017-03-06", "2017-03-12", "2017-03-14", "2017-03-22", "2017-03-28", "2017-03-29", "2017-03-29", "2017-03-30", "2017-04-11", "2017-04-22", "2017-04-29", "2017-04-29", "2017-04-29", "2017-05-01", "2017-05-03", "2017-05-05", "2017-05-07", "2017-05-21", "2017-07-06", "2018-01-01", "2018-03-17", "2018-10-28", "2018-11-13", "2019-01-22", "2019-01-26", "2019-02-02", "2019-02-13", "2019-02-15", "2019-02-23", "2019-03-04", "2019-03-24", "2019-03-26", "2019-04-11", "2019-04-18", "2019-04-25", "2019-05-09", "2019-05-13", "2019-07-26", "2019-09-26", "2019-09-29"], "y": [6, 7, 18, 16, 13, 20, 12, 25, 14, 48, 18, 18, 28, 22, 27, 42, 21, 21, 36, 29, 20, 21, 26, 24, 18, 23, 35, 25, 22, 50, 30, 50, 34, 41, 41, 19, 45, 54, 77, 36, 85, 45, 26, 56, 31, 20, 25, 35, 27, 40, 35]}, {"mode": "lines+markers", "name": "Comments", "type": "scatter", "uid": "4c4c181e-70fc-4508-995d-e1c3e3166ff1", "x": ["2015-10-12", "2015-10-14", "2017-02-12", "2017-02-12", "2017-02-13", "2017-02-14", "2017-02-14", "2017-02-15", "2017-02-17", "2017-03-02", "2017-03-04", "2017-03-06", "2017-03-12", "2017-03-14", "2017-03-22", "2017-03-28", "2017-03-29", "2017-03-29", "2017-03-30", "2017-04-11", "2017-04-22", "2017-04-29", "2017-04-29", "2017-04-29", "2017-05-01", "2017-05-03", "2017-05-05", "2017-05-07", "2017-05-21", "2017-07-06", "2018-01-01", "2018-03-17", "2018-10-28", "2018-11-13", "2019-01-22", "2019-01-26", "2019-02-02", "2019-02-13", "2019-02-15", "2019-02-23", "2019-03-04", "2019-03-24", "2019-03-26", "2019-04-11", "2019-04-18", "2019-04-25", "2019-05-09", "2019-05-13", "2019-07-26", "2019-09-26", "2019-09-29"], "y": [1, 2, 0, 2, 2, 0, 1, 1, 0, 0, 0, 0, 2, 1, 0, 1, 1, 1, 5, 0, 0, 0, 1, 0, 0, 0, 4, 0, 0, 3, 2, 4, 0, 3, 4, 0, 1, 1, 5, 3, 2, 0, 2, 4, 2, 0, 0, 0, 5, 1, 0]}],
#                         {},
#                         {"plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('c048654c-0b88-4d27-9d58-81df48346deb');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# <p style='text-align: justify;'> The bar plot shows that there's a gap betwen Sam's current follower and his post's average likes or comments. It's supported by the second plot (line plot)that tells his viewer's activity only occurs below the number of 100. But, it seems that the two variables have pretty correlation
#
# </p>

# %%
df_post.corr()
# Out:
#              likes  comments
# likes     1.000000  0.447787
# comments  0.447787  1.000000

# %% [markdown]
# # Conclusion

# %% [markdown]
# We only use several data but there are more data to collects, and more insight to be found.
#
# There are several thing that I might want to do in the future
# - collect all the comment for each post and do sentiment analysis for each post
# - classify the image into several classes and do content profiling and segmentation
